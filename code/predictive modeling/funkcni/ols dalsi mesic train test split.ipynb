# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

df = pd.read_excel(fr"C:\Users\halik\OneDrive\development\github\sws\code\predictive modeling\funkcni\funcni data set.xlsx")
x_new = df
df = df.drop(df.index[:13])
df = df.drop(df.index[-12:])

datum = df['datum']
x = df[["index", 'repo','repo-1', 'aktivni-1','nove-1','doba-1']]

y = df[['aktivni']]

x_test = x[70:]
x = x[:70]
y_test = y[70:]
y = y[:70]


#fit linear regression model
model = sm.OLS(y,x).fit()

# Predict on the test set
y_pred = model.predict(x_test)
print(y_pred)
# Evaluate the best model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)


print(f"Mean absolute error: {mae:.2f}")
print(f"Mean squared error: {mse:.2f}")
print(f"Root mean squared error: {rmse:.2f}")

#view model summary
print(model.summary())

graf =True
if graf:

    plt.plot(y_pred, label='y_pred')
    #plt.plot(y_train.values, label='y_train')
    plt.plot(y_test, label='y_test')
    plt.legend()
    plt.show()
# Out:
# 83    4510.543990
# 84    4684.631539
# 85    4757.403931
# 86    5313.406467
# 87    5581.569675
# 88    5974.843657
# 89    6176.910153
# 90    6324.038896
# 91    6832.430211
# 92    7482.375537
# 93    7981.893548
# 94    8203.055747
# 95    7691.024247
# dtype: float64
# Mean absolute error: 675.38
# Mean squared error: 563113.72
# Root mean squared error: 750.41
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                aktivni   R-squared (uncentered):                   0.996
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                              2863.
# Date:                Wed, 15 Feb 2023   Prob (F-statistic):                    9.38e-76
# Time:                        17:25:34   Log-Likelihood:                         -525.83
# No. Observations:                  70   AIC:                                      1064.
# Df Residuals:                      64   BIC:                                      1077.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# index          6.4628      5.581      1.158      0.251      -4.686      17.612
# repo           0.2990      0.727      0.411      0.682      -1.153       1.751
# repo-1        -1.4821      0.729     -2.034      0.046      -2.938      -0.027
# aktivni-1      1.1329      0.094     12.108      0.000       0.946       1.320
# nove-1        -0.4503      0.209     -2.155      0.035      -0.868      -0.033
# doba-1        -2.9953      6.129     -0.489      0.627     -15.239       9.248
# ==============================================================================
# Omnibus:                        4.299   Durbin-Watson:                   2.115
# Prob(Omnibus):                  0.117   Jarque-Bera (JB):                4.459
# Skew:                          -0.221   Prob(JB):                        0.108
# Kurtosis:                       4.154   Cond. No.                         991.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
df = pd.read_excel(fr"C:\Users\halik\OneDrive\development\github\sws\code\predictive modeling\funkcni\funcni data set.xlsx")


x_new = df.drop(df.index[:-13])
x_new = x_new.drop(x_new.index[-12:])

x_new = x_new[["index",'repo', "repo-1", "aktivni-1","nove-1", "doba-1"]]
#predikce
y_pred = model.predict(x_new)
print(y_pred)
# graf
rozsah = 24
plt.plot(x.index[-rozsah:], y[-rozsah:])
plt.scatter(x_new.index,y_pred)
# Out:
# 95    8261.317067
# dtype: float64
