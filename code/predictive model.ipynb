# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


df = df = pd.read_csv(fr'C:\Users\halik\OneDrive\development\github\sws\code\repo.csv', delimiter=',')
#df.head(5)
#print(df.corr())
#X= df[['datum', 'repo', 'cena', 'doba', 'nove', 'zobrazeni']]
X= df[['datum', 'repo']]
Y= df[['aktivni']]
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=90)
linreg= LinearRegression()
linreg.fit(X_train,y_train)

y_pred=linreg.predict(X_test)

x_new = [[202302, 700]]
y_new = linreg.predict(x_new)

from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn import metrics
from sklearn.metrics import classification_report
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print(f'zname: {x_new}, odhad: {y_new}')
print("r2: ", sklearn.metrics.r2_score(y_test, y_pred))
print(f'mean absolute error: {mae:.2f}')
print(f'mean squared error: {mse:.2f}')
print(f'root mean squared error: {rmse:.2f}')
print (X_test) #test dataset
print (y_pred) #predicted values
# Out:
# zname: [[202302, 700]], odhad: [[6875.44023486]]
# r2:  0.5354195405659423
# mean absolute error: 939.25
# mean squared error: 1349066.94
# root mean squared error: 1161.49
#       datum  repo
# 83   202106    50
# 99   202210   700
# 49   201808   125
# 63   201910   200
# 59   201906   200
# 36   201707     5
# 24   201607     5
# 90   202201   375
# 5    201412     5
# 16   201511     5
# 69   202004   100
# 92   202203   450
# 35   201706     5
# 55   201902   175
# 25   201608     5
# 101  202212   700
# 95   202206   700
# 64   201911   200
# 73   202008    25
# 97   202208   700
# 52   201811   175
# 15   201510     5
# 98   202209   700
# 61   201908   200
# 47   201806   100
# 84   202107    50
# 8    201503     5
# 41   201712    50
# 21   201604     5
# 89   202112   375
# 17   201512     5
# 76   202011    25
# 46   201805    75
# 27   201610     5
# 3    201410     5
# 20   201603     5
# 93   202204   500
# 23   201606     5
# 34   201705     5
# 81   202104    25
# ...
